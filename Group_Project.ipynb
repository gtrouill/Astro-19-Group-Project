# %% [markdown]
# Group Project
# Group Members: Gavin Rouillard , Iris, Huyhanna

# %% [markdown]
# 1) Download the dataset: go to the NASA Exoplanet ArchiveLinks to an external site. and find the 55 Cnc system overview by typing "55 Cnc" into the Explore the Archive searchbar. Scroll down until you see "Ancillary Information" and download the "Radial Velocity Curve" that has 274 points. This will open a new tab with plain text, that you can save in a text file.
#
# 2) In your Jupyter notebook, begin by using Markdown to title your report and list the names of the authors. Load the data from the saved text file. Make a plot of the radial velocity (RV) versus time; use error bars to indicate experimental uncertainty on the RV data. As always, label the axes and customize the figure for best readability.
#
# 3) Define an oscillatory function in Python to describe the variations of the radial velocity data and use the scipy library to fit this oscillatory function to the data. Follow the example from Lecture 10. Document these steps in the Jupyter notebook, and graph both the model and the data on the same plot. Provide sufficient labeling of data and the axes to provide clarity.
#
# 4) Next, subtract the best fit function from the data to obtain residuals, and plot them. Assess graphically and mathematically deviations of the measured RV signal from the model. Plot a histogram of the residuals. Modify the bin widths by trial and error to get a clear view of the distribution. Obtain from this a standard deviation of the distribution, and compare it to the assumed experimental error. This serves as an indication of the significance of the model.
#
# 5) For a planet on a circular orbit and zero inclination, the mass of the exoplanet is given by:
#  where K is the amplitude of the RV signal (in m/s), P is the period of the orbit (in days),
#  is the mass of the star in units of the mass of the Sun, and
#  is the mass of the planet in multiples of Jupiter masses. See example below. Use the amplitudes K and periods P obtained by your fit to calculate the mass of the exoplanet found in the RV data. Using information from the NASA Exoplanet ArchiveLinks to an external site., try to find the name of the exoplanet you discovered.
#
# Example of exoplanet mass calculation: the star WASP-39 has a mass of 0.918 times the mass of the Sun, and the exoplanet WASP-39 b has an amplitude
#  m/s and a period
#  days, which gives
# . The exoplanet WASP-39 b is 0.274 the mass of Jupiter.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def process():
    text = np.loadtxt('RCV.tbl.txt', skiprows=22)

    print(text[0])
    for i in text:
        text.split
    x = text[0]
    
    print(x)
    '''
    for i in data:
        x = data[1]
    x = data[1]
    print(x)
    '''

# %%
process()
# Out:
# [2.44967606e+06 1.31910004e+02 4.84000020e+00]
# [2.44967606e+06 1.31910004e+02 4.84000020e+00]
